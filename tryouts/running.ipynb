# %% [markdown]
# # Start here

# %%
from model import Seq2seqAttModel
from utils import GoodsDataset
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-84e4dfc0d3cd> in <module>
# ----> 1 from model import Seq2seqAttModel
#       2 from utils import GoodsDataset
#
# ~/PycharmProjects/goods_parser/model.py in <module>
# ----> 1 import torch
#       2 import torch.nn as nn
#       3 from torch import optim
#       4 import torch.nn.functional as F
#       5
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/torch/__init__.py in <module>
#      77 del _dl_flags
#      78
# ---> 79 from torch._C import *
#      80
#      81 __all__ += [name for name in dir(_C)
#
# ImportError: dlopen(/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/torch/_C.cpython-37m-darwin.so, 9): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
# ...

# %%
dataset = GoodsDataset(max_seq_size=128)
# Out:
# {'?': 0, '!': 1, 'Х': 2, 'Щ': 3, 'у': 4, 'Ы': 5, 'Ф': 6, 'U': 7, '5': 8, 'Q': 9, 'l': 10, ')': 11, 'ш': 12, 'Я': 13, 'q': 14, '·': 15, 'м': 16, 'Д': 17, '[': 18, 'L': 19, 'i': 20, '—': 21, 'Ш': 22, 'б': 23, 'e': 24, 'v': 25, 'У': 26, 'J': 27, '1': 28, 'М': 29, 'T': 30, 'а': 31, '#': 32, 'P': 33, 't': 34, '2': 35, 'р': 36, 'ё': 37, 'Z': 38, '_': 39, '»': 40, 'ö': 41, 'з': 42, ':': 43, 'h': 44, 'o': 45, ' ': 46, '=': 47, 'щ': 48, 'j': 49, 'ч': 50, 'А': 51, 'a': 52, 'Р': 53, '0': 54, 'Э': 55, 'ъ': 56, 'Á': 57, 'с': 58, 'R': 59, '"': 60, '*': 61, 'г': 62, 'Л': 63, ',': 64, 'Й': 65, 'т': 66, 'х': 67, 'Ю': 68, 'p': 69, 'о': 70, '«': 71, 'y': 72, "'": 73, 'ф': 74, '^': 75, 'g': 76, '9': 77, 'r': 78, 'д': 79, 's': 80, ';': 81, 'ю': 82, 'E': 83, '-': 84, '.': 85, 'в': 86, 'Ь': 87, 'H': 88, 'к': 89, 'G': 90, 'b': 91, 'Ж': 92, 'Е': 93, '8': 94, '+': 95, '4': 96, 'К': 97, 'x': 98, 'z': 99, 'n': 100, 'B': 101, '&': 102, 'е': 103, 'Г': 104, 'K': 105, '6': 106, '7': 107, 'O': 108, 'F': 109, 'X': 11
# ...

# %%
model = Seq2seqAttModel(dataset)

# %%
model.train(n_iters=75000)
# Out:
# 0m 20s (- 51m 26s) (500 0%) NLL = 2.4317
# ['4', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!', '!']
# ...
